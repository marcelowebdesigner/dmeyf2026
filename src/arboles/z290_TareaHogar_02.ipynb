# %% [markdown]
# # Tarea para el Hogar 02

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la segunda clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 03, ya que se analizarán los resultados

# %% [markdown]
# ##  1. Ensembles de Modelos

# %% [markdown]
# Vea el siguiente video [BBC - The Code - The Wisdom of the Crowd](https://www.youtube.com/watch?v=iOucwX7Z1HU)    ( 5 min)

# %% [markdown]
# Lea los siguientes artículos
#
#
# *   [The Wisdom of Crowds (Vox Populi) by Francis Galton](https://www.all-about-psychology.com/the-wisdom-of-crowds.html)  (10 min)
# *   [A Gentle Introduction to Ensemble Learning](https://machinelearningmastery.com/what-is-ensemble-learning/)  (10 min)

# %% [markdown]
# ---

# %% [markdown]
# ##  2.  Zero2Hero   primera parte
# Se han lanzado los primeros fascículos coleccionables llamados "from Zero to Hero" que muy detalladamente, paso a paso enseñan todo lo necesario de R para entender los scripts oficiales de la asignatura.
# Están en el repositorio oficial de la asignatura, carpeta  **src/zero2hero**

# %% [markdown]
# ---

# %% [markdown]
# ## 3.  Grid Search

# %% [markdown]
# Busque en internet el precido significado de los hiperparámetros de la librería **rpart**  que está implementando el algoritmo **CART**  Classification and Regression Trees  propuesto en el año 1984 por Leo Brieman:
#
# *   cp
# *   maxdepth
# *   minsplit
# *   minbucket
#
# Entienda que valores es razonable tome cada hiperparámetro,  en particular profundice en el hiperparámetro  **cp**  y la posibilidad que tome valores negativos.  Es válido consultar a su amigo de *capacidades especiales*  ChatGPT

# %% [markdown]
# En las siguientes celdas a un notebook incompleto, un esqueleto de codigo brindado a modo de facilitarle la tarea de codeo y permitir que su valiosa cognición se concentre temas conceptuales de Ciencia de Datos
#
# Modifiquelo agregando loops para que recorra TODOS los hiperparámetros de rpart  < cp, maxdepth, minsplit, minbucket >, y luego póngalo a correr. Recuerde cambiar por SU semilla
# Tenga muy presente la granularidad que eligirá para cada hiperparámetro.

# %% [markdown]
# ### Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}


# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"
# Out:
# cp: cannot stat '/content/buckets/b1/kaggle/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %% [markdown]
# limpio el ambiente de R

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  668150 35.7 1473300    78.7 1425901  76.2
# Vcells 1236290  9.5 8388608    64.0 1978711  15.1

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
require("parallel")
if (!require("primes")) install.packages("primes")
require("primes")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: rpart
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes

# %% [markdown]
# Aqui debe poner SU semiila primigenia

# %%
PARAM <- list()
# reemplazar por su primer semilla
PARAM$semilla_primigenia <- 200003
PARAM$qsemillas <- 1

PARAM$training_pct <- 70L  # entre  1L y 99L

# elegir SU dataset comentando/ descomentando
PARAM$dataset_nom <- "~/datasets/dataset_pequeno.csv"

# %%
# particionar agrega una columna llamada fold a un dataset
#  que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30), agrupa=clase_ternaria, seed=semilla)
#   crea una particion 70, 30

particionar <- function(data, division, agrupa = "", campo = "fold", start = 1, seed = NA) {
  if (!is.na(seed)) set.seed(seed)

  bloque <- unlist(mapply(function(x, y) {
    rep(y, x)
  }, division, seq(from = start, length.out = length(division))))

  data[, (campo) := sample(rep(bloque, ceiling(.N / length(bloque))))[1:.N],
    by = agrupa
  ]
}

# %%
ArbolEstimarGanancia <- function(semilla, training_pct, param_basicos) {
  # particiono estratificadamente el dataset
  particionar(dataset,
    division = c(training_pct, 100L -training_pct),
    agrupa = "clase_ternaria",
    seed = semilla # aqui se usa SU semilla
  )

  # genero el modelo
  # predecir clase_ternaria a partir del resto
  modelo <- rpart("clase_ternaria ~ .",
    data = dataset[fold == 1], # fold==1  es training,  el 70% de los datos
    xval = 0,
    control = param_basicos
  ) # aqui van los parametros del arbol

  # aplico el modelo a los datos de testing
  prediccion <- predict(modelo, # el modelo que genere recien
    dataset[fold == 2], # fold==2  es testing, el 30% de los datos
    type = "prob"
  ) # type= "prob"  es que devuelva la probabilidad

  # prediccion es una matriz con TRES columnas,
  #  llamadas "BAJA+1", "BAJA+2"  y "CONTINUA"
  # cada columna es el vector de probabilidades


  # calculo la ganancia en testing  qu es fold==2
  ganancia_test <- dataset[
    fold == 2,
    sum(ifelse(prediccion[, "BAJA+2"] > 0.025,
      ifelse(clase_ternaria == "BAJA+2", 975000, -25000),
      0
    ))
  ]

  # escalo la ganancia como si fuera todo el dataset
  ganancia_test_normalizada <- ganancia_test / (( 100 - PARAM$training_pct ) / 100 )

  return(
    c( list("semilla" = semilla),
      param_basicos,
      list( "ganancia_test" = ganancia_test_normalizada )
     )
  )
}

# %%
ArbolesMontecarlo <- function(semillas, param_basicos) {

  # la funcion mcmapply  llama a la funcion ArbolEstimarGanancia
  #  tantas veces como valores tenga el vector  PARAM$semillas
  salida <- mcmapply(ArbolEstimarGanancia,
    semillas, # paso el vector de semillas
    MoreArgs = list(PARAM$training_pct, param_basicos), # aqui paso el segundo parametro
    SIMPLIFY = FALSE,
    mc.cores = detectCores()
  )

  return(salida)
}

# %%
# carpeta de trabajo
# por fabor cambiar numero de experimento si se cambia el loop principal
setwd("/content/buckets/b1/exp")
experimento <- "HT2900"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# trabajo solo con los datos con clase, es decir 202107
dataset <- dataset[clase_ternaria != ""]

# %%
# genero numeros primos
primos <- generate_primes(min = 100000, max = 1000000)
set.seed(PARAM$semilla_primigenia) # inicializo
# me quedo con PARAM$qsemillas   semillas
PARAM$semillas <- sample(primos, PARAM$qsemillas )

# %%
# genero la data.table donde van los resultados detallados del Grid Search
# un registro para cada combinacion de < semilla, parametros >

if(file.exists("gridsearch_detalle.txt")){
  tb_grid_search_detalle <- fread("gridsearch_detalle.txt")
}else{
  tb_grid_search_detalle <- data.table(
    semilla = integer(),
    cp = numeric(),
    maxdepth = integer(),
    minsplit = integer(),
    minbucket = integer(),
    ganancia_test = numeric()
  )
}

nrow( tb_grid_search_detalle )
# Out:
# [1] 1170

# %% [markdown]
# Esta es la parte del código que usted debe expandir a TODOS los hiperparámetros de rpart,
# <br>ya que actualmente apenas recorre  maxdepth y  minsplit  dejando fijos  cp=-0.5  y minbucket=5

# %%
iter <- 0
vcp_fijo <- -0.5  # Desactiva poda por complejidad; el control queda en depth/split/bucket

for (vmax_depth in c(4, 6, 8, 10, 12, 14)) {
  for (vmin_split in c(1000, 500, 200, 50, 10)) {
    for (vmin_bucket in c(2, 5, 10, 20, 50)) {

      # Regla de consistencia
      if (vmin_bucket > (vmin_split / 2)) next

      iter <- iter + 1
      cat(sprintf("Iteración: %d | Depth: %d | MinSplit: %d | MinBucket: %d\n",
                  iter, vmax_depth, vmin_split, vmin_bucket))
      flush.console()

      # Checkpoint de recuperación
      if (iter * PARAM$qsemillas < nrow(tb_grid_search_detalle) + 1) next

      # Configuración del punto en la grilla
      param_basicos <- list(
        "cp"        = vcp_fijo,
        "maxdepth"  = vmax_depth,
        "minsplit"  = vmin_split,
        "minbucket" = vmin_bucket
      )

      # Evaluación Monte Carlo
      ganancias <- ArbolesMontecarlo(PARAM$semillas, param_basicos)

      # Acumulación de resultados
      tb_grid_search_detalle <- rbindlist(
        list(
          tb_grid_search_detalle,
          rbindlist(ganancias)
        )
      )
    }
  }

  # Persistencia a disco en el loop externo
  fwrite(
    tb_grid_search_detalle,
    file = "gridsearch_detalle.txt",
    sep  = "\t"
  )
}
# Out:
# Iteración: 1 | Depth: 4 | MinSplit: 1000 | MinBucket: 2
# Iteración: 2 | Depth: 4 | MinSplit: 1000 | MinBucket: 5
# Iteración: 3 | Depth: 4 | MinSplit: 1000 | MinBucket: 10
# Iteración: 4 | Depth: 4 | MinSplit: 1000 | MinBucket: 20
# Iteración: 5 | Depth: 4 | MinSplit: 1000 | MinBucket: 50
# Iteración: 6 | Depth: 4 | MinSplit: 500 | MinBucket: 2
# Iteración: 7 | Depth: 4 | MinSplit: 500 | MinBucket: 5
# Iteración: 8 | Depth: 4 | MinSplit: 500 | MinBucket: 10
# Iteración: 9 | Depth: 4 | MinSplit: 500 | MinBucket: 20
# Iteración: 10 | Depth: 4 | MinSplit: 500 | MinBucket: 50
# Iteración: 11 | Depth: 4 | MinSplit: 200 | MinBucket: 2
# Iteración: 12 | Depth: 4 | MinSplit: 200 | MinBucket: 5
# Iteración: 13 | Depth: 4 | MinSplit: 200 | MinBucket: 10
# Iteración: 14 | Depth: 4 | MinSplit: 200 | MinBucket: 20
# Iteración: 15 | Depth: 4 | MinSplit: 200 | MinBucket: 50
# Iteración: 16 | Depth: 4 | MinSplit: 50 | MinBucket: 2
# Iteración: 17 | Depth: 4 | MinSplit: 50 | MinBucket: 5
# Iteración: 18 | Depth: 4 | MinSplit: 50 | MinBucket: 10
# Iteración: 19 | Depth: 4 | MinSplit: 50 | MinBucket: 20
# Iteración: 20 | Depth: 4 | MinSplit: 10 | MinBucket: 2
# Iteración: 21 | Depth: 4 | MinSplit: 10 | MinBucket: 5
# Iteración: 22 | Depth: 6 | MinSplit: 1000 | MinBucket: 2
# Iteración: 23 | Depth: 6 | MinSplit: 1000 | MinBucket: 5
# Iteración: 24 | Depth: 6 | MinSplit: 1000 | MinBucket: 10
# Iteración: 25 | Depth: 6 | MinSplit: 1000 | MinBucket: 20
# Iteración: 26 | Depth: 6 | MinSplit: 1000 | MinBucket: 50
# Iteración: 27 | Depth: 6 | MinSplit: 500 | MinBucket: 2
# Iteración: 28 | Depth: 6 | MinSplit: 500 | MinBucket: 5
# Iteración: 29 | Depth: 6 | MinSplit: 500 | MinBucket: 10
# Iteración: 30 | Depth: 6 | MinSplit: 500 | MinBucket: 20
# Iteración: 31 | Depth: 6 | MinSplit: 500 | MinBucket: 50
# Iteración: 32 | Depth: 6 | MinSplit: 200 | MinBucket: 2
# Iteración: 33 | Depth: 6 | MinSplit: 200 | MinBucket: 5
# Iteración: 34 | Depth: 6 | MinSplit: 200 | MinBucket: 10
# Iteración: 35 | Depth: 6 | MinSplit: 200 | MinBucket: 20
# Iteración: 36 | Depth: 6 | MinSplit: 200 | MinBucket: 50
# Iteración: 37 | Depth: 6 | MinSplit: 50 | MinBucket: 2
# Iteración: 38 | Depth: 6 | MinSplit: 50 | MinBucket: 5
# Iteración: 39 | Depth: 6 | MinSplit: 50 | MinBucket: 10
# Iteración: 40 | Depth: 6 | MinSplit: 50 | MinBucket: 20
# Iteración: 41 | Depth: 6 | MinSplit: 10 | MinBucket: 2
# Iteración: 42 | Depth: 6 | MinSplit: 10 | MinBucket: 5
# Iteración: 43 | Depth: 8 | MinSplit: 1000 | MinBucket: 2
# Iteración: 44 | Depth: 8 | MinSplit: 1000 | MinBucket: 5
# Iteración: 45 | Depth: 8 | MinSplit: 1000 | MinBucket: 10
# Iteración: 46 | Depth: 8 | MinSplit: 1000 | MinBucket: 20
# Iteración: 47 | Depth: 8 | MinSplit: 1000 | MinBucket: 50
# Iteración: 48 | Depth: 8 | MinSplit: 500 | MinBucket: 2
# Iteración: 49 | Depth: 8 | MinSplit: 500 | MinBucket: 5
# Iteración: 50 | Depth: 8 | MinSplit: 500 | MinBucket: 10
# Iteración: 51 | Depth: 8 | MinSplit: 500 | MinBucket: 20
# Iteración: 52 | Depth: 8 | MinSplit: 500 | MinBucket: 50
# Iteración: 53 | Depth: 8 | MinSplit: 200 | MinBucket: 2
# Iteración: 54 | Depth: 8 | MinSplit: 200 | MinBucket: 5
# Iteración: 55 | Depth: 8 | MinSplit: 200 | MinBucket: 10
# Iteración: 56 | Depth: 8 | MinSplit: 200 | MinBucket: 20
# Iteración: 57 | Depth: 8 | MinSplit: 200 | MinBucket: 50
# Iteración: 58 | Depth: 8 | MinSplit: 50 | MinBucket: 2
# Iteración: 59 | Depth: 8 | MinSplit: 50 | MinBucket: 5
# Iteración: 60 | Depth: 8 | MinSplit: 50 | MinBucket: 10
# Iteración: 61 | Depth: 8 | MinSplit: 50 | MinBucket: 20
# Iteración: 62 | Depth: 8 | MinSplit: 10 | MinBucket: 2
# Iteración: 63 | Depth: 8 | MinSplit: 10 | MinBucket: 5
# Iteración: 64 | Depth: 10 | MinSplit: 1000 | MinBucket: 2
# Iteración: 65 | Depth: 10 | MinSplit: 1000 | MinBucket: 5
# Iteración: 66 | Depth: 10 | MinSplit: 1000 | MinBucket: 10
# Iteración: 67 | Depth: 10 | MinSplit: 1000 | MinBucket: 20
# Iteración: 68 | Depth: 10 | MinSplit: 1000 | MinBucket: 50
# Iteración: 69 | Depth: 10 | MinSplit: 500 | MinBucket: 2
# Iteración: 70 | Depth: 10 | MinSplit: 500 | MinBucket: 5
# Iteración: 71 | Depth: 10 | MinSplit: 500 | MinBucket: 10
# Iteración: 72 | Depth: 10 | MinSplit: 500 | MinBucket: 20
# Iteración: 73 | Depth: 10 | MinSplit: 500 | MinBucket: 50
# Iteración: 74 | Depth: 10 | MinSplit: 200 | MinBucket: 2
# Iteración: 75 | Depth: 10 | MinSplit: 200 | MinBucket: 5
# Iteración: 76 | Depth: 10 | MinSplit: 200 | MinBucket: 10
# Iteración: 77 | Depth: 10 | MinSplit: 200 | MinBucket: 20
# Iteración: 78 | Depth: 10 | MinSplit: 200 | MinBucket: 50
# Iteración: 79 | Depth: 10 | MinSplit: 50 | MinBucket: 2
# Iteración: 80 | Depth: 10 | MinSplit: 50 | MinBucket: 5
# Iteración: 81 | Depth: 10 | MinSplit: 50 | MinBucket: 10
# Iteración: 82 | Depth: 10 | MinSplit: 50 | MinBucket: 20
# Iteración: 83 | Depth: 10 | MinSplit: 10 | MinBucket: 2
# Iteración: 84 | Depth: 10 | MinSplit: 10 | MinBucket: 5
# Iteración: 85 | Depth: 12 | MinSplit: 1000 | MinBucket: 2
# Iteración: 86 | Depth: 12 | MinSplit: 1000 | MinBucket: 5
# Iteración: 87 | Depth: 12 | MinSplit: 1000 | MinBucket: 10
# Iteración: 88 | Depth: 12 | MinSplit: 1000 | MinBucket: 20
# Iteración: 89 | Depth: 12 | MinSplit: 1000 | MinBucket: 50
# Iteración: 90 | Depth: 12 | MinSplit: 500 | MinBucket: 2
# Iteración: 91 | Depth: 12 | MinSplit: 500 | MinBucket: 5
# Iteración: 92 | Depth: 12 | MinSplit: 500 | MinBucket: 10
# Iteración: 93 | Depth: 12 | MinSplit: 500 | MinBucket: 20
# Iteración: 94 | Depth: 12 | MinSplit: 500 | MinBucket: 50
# Iteración: 95 | Depth: 12 | MinSplit: 200 | MinBucket: 2
# Iteración: 96 | Depth: 12 | MinSplit: 200 | MinBucket: 5
# Iteración: 97 | Depth: 12 | MinSplit: 200 | MinBucket: 10
# Iteración: 98 | Depth: 12 | MinSplit: 200 | MinBucket: 20
# Iteración: 99 | Depth: 12 | MinSplit: 200 | MinBucket: 50
# Iteración: 100 | Depth: 12 | MinSplit: 50 | MinBucket: 2
# Iteración: 101 | Depth: 12 | MinSplit: 50 | MinBucket: 5
# Iteración: 102 | Depth: 12 | MinSplit: 50 | MinBucket: 10
# Iteración: 103 | Depth: 12 | MinSplit: 50 | MinBucket: 20
# Iteración: 104 | Depth: 12 | MinSplit: 10 | MinBucket: 2
# Iteración: 105 | Depth: 12 | MinSplit: 10 | MinBucket: 5
# Iteración: 106 | Depth: 14 | MinSplit: 1000 | MinBucket: 2
# Iteración: 107 | Depth: 14 | MinSplit: 1000 | MinBucket: 5
# Iteración: 108 | Depth: 14 | MinSplit: 1000 | MinBucket: 10
# Iteración: 109 | Depth: 14 | MinSplit: 1000 | MinBucket: 20
# Iteración: 110 | Depth: 14 | MinSplit: 1000 | MinBucket: 50
# Iteración: 111 | Depth: 14 | MinSplit: 500 | MinBucket: 2
# Iteración: 112 | Depth: 14 | MinSplit: 500 | MinBucket: 5
# Iteración: 113 | Depth: 14 | MinSplit: 500 | MinBucket: 10
# Iteración: 114 | Depth: 14 | MinSplit: 500 | MinBucket: 20
# Iteración: 115 | Depth: 14 | MinSplit: 500 | MinBucket: 50
# Iteración: 116 | Depth: 14 | MinSplit: 200 | MinBucket: 2
# Iteración: 117 | Depth: 14 | MinSplit: 200 | MinBucket: 5
# Iteración: 118 | Depth: 14 | MinSplit: 200 | MinBucket: 10
# Iteración: 119 | Depth: 14 | MinSplit: 200 | MinBucket: 20
# Iteración: 120 | Depth: 14 | MinSplit: 200 | MinBucket: 50
# Iteración: 121 | Depth: 14 | MinSplit: 50 | MinBucket: 2
# Iteración: 122 | Depth: 14 | MinSplit: 50 | MinBucket: 5
# Iteración: 123 | Depth: 14 | MinSplit: 50 | MinBucket: 10
# Iteración: 124 | Depth: 14 | MinSplit: 50 | MinBucket: 20
# Iteración: 125 | Depth: 14 | MinSplit: 10 | MinBucket: 2
# Iteración: 126 | Depth: 14 | MinSplit: 10 | MinBucket: 5

# %%
fwrite( tb_grid_search_detalle,
   file = "gridsearch_detalle.txt",
   sep = "\t"
)

# %%
# cantidad de registros de la tabla
nrow(tb_grid_search_detalle)
# Out:
# [1] 1170

# %%
# muestro la tabla
tb_grid_search_detalle
# Out:
#      semilla cp     maxdepth minsplit minbucket ganancia_test
# 1    590819  -1.000 4        1000      2        507916667
# 2    590819  -0.500 4        1000      2        507916667
# 3    590819   0.000 4        1000      2        497500000
# 4    590819   0.001 4        1000      2                0
# 5    590819   0.010 4        1000      2                0
# 6    590819  -1.000 4        1000      5        490000000
# 7    590819  -0.500 4        1000      5        490000000
# 8    590819   0.000 4        1000      5                0
# 9    590819   0.001 4        1000      5                0
# 10   590819   0.010 4        1000      5                0
# 11   590819  -1.000 4        1000     10        490000000
# 12   590819  -0.500 4        1000     10        490000000
# 13   590819   0.000 4        1000     10                0
# 14   590819   0.001 4        1000     10                0
# 15   590819   0.010 4        1000     10                0
# 16   590819  -1.000 4        1000     20        493666667
# 17   590819  -0.500 4        1000     20        493666667
# 18   590819   0.000 4        1000     20                0
# 19   590819   0.001 4        1000     20                0
# 20   590819   0.010 4        1000     20                0
# 21   590819  -1.000 4        1000     50        487750000
# 22   590819  -0.500 4        1000     50        487750000
# 23   590819   0.000 4        1000     50                0
# 24   590819   0.001 4        1000     50                0
# 25   590819   0.010 4        1000     50                0
# 26   590819  -1.000 4         800      2        507916667
# 27   590819  -0.500 4         800      2        507916667
# 28   590819   0.000 4         800      2        497500000
# 29   590819   0.001 4         800      2                0
# 30   590819   0.010 4         800      2                0
# ⋮    ⋮       ⋮      ⋮        ⋮        ⋮         ⋮
# 1141 590819  -1.000 14       50       20        415250000
# 1142 590819  -0.500 14       50       20        415250000
# 1143 590819   0.000 14       50       20        492750000
# 1144 590819   0.001 14       50       20        335250000
# 1145 590819   0.010 14       50       20                0
# 1146 590819  -1.000 14       20        2        332666667
# 1147 590819  -0.500 14       20        2        332666667
# 1148 590819   0.000 14       20        2        416916667
# 1149 590819   0.001 14       20        2        319333333
# 1150 590819   0.010 14       20        2                0
# 1151 590819  -1.000 14       20        5        306416667
# 1152 590819  -0.500 14       20        5        306416667
# 1153 590819   0.000 14       20        5        432000000
# 1154 590819   0.001 14       20        5        335250000
# 1155 590819   0.010 14       20        5                0
# 1156 590819  -1.000 14       20       10        271333333
# 1157 590819  -0.500 14       20       10        271333333
# 1158 590819   0.000 14       20       10        435666667
# 1159 590819   0.001 14       20       10        335250000
# 1160 590819   0.010 14       20       10                0
# 1161 590819  -1.000 14       10        2        315666667
# 1162 590819  -0.500 14       10        2        315666667
# 1163 590819   0.000 14       10        2        401750000
# 1164 590819   0.001 14       10        2        473666667
# 1165 590819   0.010 14       10        2                0
# 1166 590819  -1.000 14       10        5        281583333
# 1167 590819  -0.500 14       10        5        281583333
# 1168 590819   0.000 14       10        5        387166667
# 1169 590819   0.001 14       10        5        489250000
# 1170 590819   0.010 14       10        5                0

# %%
# genero y grabo el resumen
tb_grid_search <- tb_grid_search_detalle[,
  list( "ganancia_mean" = mean(ganancia_test),
    "qty" = .N ),
  list( cp, maxdepth, minsplit, minbucket )
]

# %%
# ordeno descendente por ganancia
setorder( tb_grid_search, -ganancia_mean )

# %%
# veo los 10 mejores hiperparámetros
tb_grid_search[1:10]
# Out:
#    cp   maxdepth minsplit minbucket ganancia_mean qty
# 1  -1.0 10       200      20        514250000     1
# 2  -0.5 10       200      20        514250000     1
# 3  -1.0 10       400      20        513500000     1
# 4  -0.5 10       400      20        513500000     1
# 5  -1.0  8       100      20        510416667     1
# 6  -0.5  8       100      20        510416667     1
# 7  -1.0  8       400      20        509916667     1
# 8  -0.5  8       400      20        509916667     1
# 9  -1.0  8        50      20        509583333     1
# 10 -0.5  8        50      20        509583333     1

# %%
# genero un id a la tabla
tb_grid_search[, id := .I ]

fwrite( tb_grid_search,
  file = "gridsearch.txt",
  sep = "\t"
)

# %% [markdown]
# # 4.  Análisis de resultados de Grid Search

# %% [markdown]
# La salida de la corrida anterior queda en ~/buckets/b1/exp/HT2900  que corresponde a su Google Drive
# <br>HT significa Hyperparameter Tuning
# <br>El Grid Search es un método de fuerza bruta de un altísimo costo computacional.
# <br>Queremos ver si es posible crear un algoritmo de optimización de hiperparámetros que se ahorre recorrer ciertas porciones muy malas del espacio de búsqueda. Algo del estilo “cada vez que pruebo una combinación de hiperparámetros donde  cp > 1 , la ganancia es muy mala, con lo cual ni vale la pena perder el tiempo explorando en esa region”

# %% [markdown]
# <br>Levante el archivo de salida gridsearch.txt  a una planilla tipo Excel y analícelo detenidamente
# <br>Ordene por ganancia_mean descendente
# <br>
# <br>En la Planilla Colaborativa, Hoja  C3-GridSearch  cargue el mejor del ranking en la posición 1, el segundo en la 2, y el 5, 10, 50 y 100. Es decir debe cargr SEIS lineas en las celdas correspondientes a su nombre.
# <br>
# <br>Verifique que efectivamente está dado de alta en la competencia Kaggle  "Data Mining, Inicial 2026 B"  lo que debio haber hecho siguiendo el capítulo Arranque en Frio de El Libro de la Asignatura
# <br>En la Planilla Colaborativa, Hoja  C3-GridSearch, utilizando el notebook  **src/arboles/z102_FinalTrain.ipynb**  haga el submit a Kaggle de cada una de las SEIS combinaciones de hiperparámetros y completa la columna Public Leaderboard
#
# <br>
# <br>El de mayor ganancia_mean  decimos que es el primero del ranking
# En Zulip, correspondiente channel  #Tarea Hogar 02 , topic Analisis Grid Search   intente contestar estas preguntas:
#
# * ¿Qué combinaciones de hiperparámetros poseen una ganancia muy buena?
# * ¿Hay algun hiperparámetro que para cierto valor siempre genera una ganancia muy mala, a independientemente de lo que valgan los otros hiperparámetros ?
# * ¿Que combinaciones de hiperparámetros es pésima y hubiera sido bueno ahorrarse esas corridas ?
#
# ( tiempo estimado 40 minutos, dificultad media )
